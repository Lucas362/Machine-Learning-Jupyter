# %% [markdown]
# <h1>Venda de jogos de videogames na história</h1>
# <br>
# Esta apresentação foi criada por <b>Paulo Henrique Vasconcellos</b>. Aqui irei realizar algumas análises sobre os dados encontrados <a href="https://www.kaggle.com/gregorut/videogamesales">neste dataset</a>.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#Leitura do arquivo
videogames = pd.read_csv('vgsales.csv')

# %%
#Exibindo as 10 primeiras linhas do DataFrame
videogames.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
videogames.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
videogames.shape
# Out:
# (16598, 11)

# %%
#Renomeando colunas
videogames.columns = ['Ranking', 'Nome', 'Plataforma', 'Ano',
'Gênero', 'Editora', 'Vendas América do Norte', 'Vendas EUA',                     'Vendas Japão', 'Outras vendas', 'Vendas Global']

# %%
#Exibindo as 10 primeiras linhas do DataFrame
videogames.head(10)
# Out:
#    Ranking                       Nome Plataforma     Ano        Gênero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#     Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  Outras vendas  \
# 0  Nintendo                    41.49       29.02          3.77           8.46
# ...

# %%
#verificando linhas em que não há ano de lançamento definido
videogames[videogames['Ano'].isnull()].head()
# Out:
#      Ranking                        Nome Plataforma  Ano    Gênero  \
# 179      180             Madden NFL 2004        PS2  NaN    Sports
# 377      378            FIFA Soccer 2004        PS2  NaN    Sports
# 431      432  LEGO Batman: The Videogame        Wii  NaN    Action
# 470      471  wwe Smackdown vs. Raw 2006        PS2  NaN  Fighting
# 607      608              Space Invaders       2600  NaN   Shooter
#
#                                     Editora  Vendas América do Norte  \
# 179                         Electronic Arts                     4.26
# 377                         Electronic Arts                     0.59
# 431  Warner Bros. Interactive Entertainment                     1.86
# 470                                     NaN                     1.57
# 607                                   Atari                     2.36
#
#      Vendas EUA  Vendas Japão  Outras vendas  Vendas Global
# 179        0.26          0.01           0.71           5.23
# ...

# %%
titulos_lancados = videogames['Plataforma'].value_counts()
titulos_lancados.plot()
videogames['Plataforma'].value_counts().plot()
